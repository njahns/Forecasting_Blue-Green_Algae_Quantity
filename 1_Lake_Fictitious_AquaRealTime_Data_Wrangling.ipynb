# %% [markdown]
# The purpose of this capstone is to accurately predict the quantity of phycocyanin and identify the most important predictors of water quality metrics for making these estimates. In other words, the main goal is to predict the 'phycocyanin' column with the explanatory variables and then perform feature importance.

# %% [markdown]
# # 1. Data Wrangling

# %%
# Libraries imported for this notebook.

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, DayLocator, DateFormatter
from scipy.interpolate import interp1d
import numpy as np

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# AquaRealTime provided a login to their data portal from which I downloaded Lake Fictitious data.

# %%
# Read Lake_Fictitious_AquaRealTime_Data_Orig into a dataframe, formatted dates, and indexed dates.

df_orig = pd.read_csv('Lake_Fictitious_AquaRealTime_Data_Orig.csv', parse_dates=True, index_col=[1])

# %%
# Explored dimensions.

df_orig.shape
# Out:
# (50071, 20)

# %% [markdown]
# Confirmed that I should have sufficient rows of data to create regression models.

# %%
# Viewed dataframe.

df_orig
# Out:
#                      Unnamed: 0     utcTime       light   airTemp  waterTemp  \
# timeString
# 2021-01-27 11:01:20         NaN  1611774080  483.200012  0.000000       11.5
# 2021-01-27 11:01:20         NaN  1611774080  483.200012  0.000000       11.5
# 2021-01-27 11:01:20         NaN  1611774080  483.200012  0.000000       11.5
# 2021-01-27 11:01:20         NaN  1611774080  483.200012  0.000000       11.5
# 2021-01-27 11:01:20         NaN  1611774080  483.200012  0.000000       11.5
# ...                         ...         ...         ...       ...        ...
# 2024-02-23 05:30:40         NaN  1708695040    0.000000  8.510274       15.0
# 2024-02-23 06:00:32         NaN  1708696832    0.000000  8.510274       14.9
# 2024-02-23 06:30:24         NaN  1708698624    5.200000  9.726027       14.8
# 2024-02-23 07:00:16         NaN  1708700416  172.600006  9.726027       14.8
# 2024-02-23 07:30:08         NaN  1708702208  204.000000  9.726027       14.9
#
#                      turbidity  phycocyanin      chlorA  waterLight  \
# timeString
# 2021-01-27 11:01:20  23.959999        24.43  228.550003          15
# 2021-01-27 11:01:20  23.959999        24.43  228.550003          15
# 2021-01-27 11:01:20  23.959999        24.43  228.550003          15
# 2021-01-27 11:01:20  23.959999        24.43  228.550003          15
# 2021-01-27 11:01:20  23.959999        24.43  228.550003          15
# ...                        ...          ...         ...         ...
# 2024-02-23 05:30:40   2.210000         8.51   96.839996          29
# 2024-02-23 06:00:32   2.400000         8.51   93.339996          29
# 2024-02-23 06:30:24   2.210000         9.72   94.510002          29
# 2024-02-23 07:00:16   2.210000         9.72   93.339996          29
# 2024-02-23 07:30:08   2.600000         9.72   93.339996          35
#
#                       buoyTemp  battVolts    battSOC  sigStrength  sigQuality  \
# timeString
# 2021-01-27 11:01:20  17.299999        4.0  96.900002    34.374001           1
# 2021-01-27 11:01:20  17.299999        4.0  96.900002    34.374001           1
# 2021-01-27 11:01:20  17.299999        4.0  96.900002    34.374001           1
# 2021-01-27 11:01:20  17.299999        4.0  96.900002    34.374001           1
# 2021-01-27 11:01:20  17.299999        4.0  96.900002    34.374001           1
# ...                        ...        ...        ...          ...         ...
# 2024-02-23 05:30:40  14.500000        3.9  81.300003    54.999619          67
# 2024-02-23 06:00:32  14.100000        3.9  81.099998    54.999619          67
# 2024-02-23 06:30:24  13.900000        3.9  80.900002    54.999619          67
# 2024-02-23 07:00:16  14.100000        3.9  80.900002    54.999619          68
# 2024-02-23 07:30:08  14.300000        3.9  80.699997    60.000004          68
#
#                      codeVersion  panelVolts  leakDetect  phycocyaninTrend  \
# timeString
# 2021-01-27 11:01:20      2101252        19.5          -1            26.430
# 2021-01-27 11:01:20      2101252        19.5          -1            26.430
# 2021-01-27 11:01:20      2101252        19.5          -1            26.430
# 2021-01-27 11:01:20      2101252        19.5          -1            26.430
# 2021-01-27 11:01:20      2101252        19.5          -1            26.430
# ...                          ...         ...         ...               ...
# 2024-02-23 05:30:40       230209         0.1          25            10.422
# 2024-02-23 06:00:32       230209         0.2          27            10.403
# 2024-02-23 06:30:24       230209         4.8          32            10.396
# 2024-02-23 07:00:16       230209        16.5          32            10.390
# 2024-02-23 07:30:08       230209        16.5          31            10.401
#
#                      chlorATrend  turbidityTrend
# timeString
# 2021-01-27 11:01:20      248.550          28.792
# 2021-01-27 11:01:20      248.550          28.792
# 2021-01-27 11:01:20      248.550          28.792
# 2021-01-27 11:01:20      248.550          28.792
# 2021-01-27 11:01:20      248.550          28.792
# ...                          ...             ...
# 2024-02-23 05:30:40       97.973           4.597
# 2024-02-23 06:00:32       97.741           4.575
# 2024-02-23 06:30:24       97.580           4.551
# 2024-02-23 07:00:16       97.381           4.528
# 2024-02-23 07:30:08       97.610           4.526
#
# [50071 rows x 20 columns]

# %% [markdown]
# Data looks in very good condition. Little cleaning to be done. I can see right away that reading at the beginnig of the study were collected every hour but switched to every half and hour at some point. Also, I have an empty column and some duplicate rows.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Columns

# %%
# Removed unneeded columns.

df = df_orig[['phycocyanin', 'light', 'waterTemp', 'turbidity', 'chlorA']].copy()

# %%
# Rounded times to the nearest half hour so I have simpler times to work with.

df.index = df.index.round('30min')

# %% [markdown]
# ### Duplicate Rows

# %%
# Checked for duplicate rows

duplicate_rows = df.index.duplicated(keep=False)
df[duplicate_rows]
# Out:
#                      phycocyanin       light  waterTemp  turbidity      chlorA
# timeString
# 2021-01-27 11:00:00    24.430000  483.200012  11.500000  23.959999  228.550003
# 2021-01-27 11:00:00    24.430000  483.200012  11.500000  23.959999  228.550003
# 2021-01-27 11:00:00    24.430000  483.200012  11.500000  23.959999  228.550003
# 2021-01-27 11:00:00    24.430000  483.200012  11.500000  23.959999  228.550003
# 2021-01-27 11:00:00    24.430000  483.200012  11.500000  23.959999  228.550003
# ...                          ...         ...        ...        ...         ...
# 2023-10-02 08:00:00    58.349998  321.299988  20.700001  10.080000  168.020004
# 2023-11-05 01:00:00    38.900002    0.000000  16.400000   7.520000  415.399994
# 2023-11-05 01:30:00    38.900002    0.000000  16.299999   8.110000  418.899994
# 2023-11-05 01:00:00    40.110001    0.000000  16.200001   8.310000  421.230011
# 2023-11-05 01:30:00    46.189999    0.000000  16.000000   8.510000  445.739990
#
# [421 rows x 5 columns]

# %% [markdown]
# Many duplicate datetimes. Need to fix this. I don't want to just delete the second occurrence because I sometimes have slightly different data for the same datetimes. Taking the average is more appropriate.

# %%
# Removed duplicates by takeing mean of values with the same date and time.

df = df.groupby(df.index).mean()

# %%
# Confirmed no duplicate rows.

duplicate_rows = df.index.duplicated(keep=False)
df[duplicate_rows]
# Out:
# Empty DataFrame
# Columns: [phycocyanin, light, waterTemp, turbidity, chlorA]
# Index: []

# %%
# Confirmed changes.

df
# Out:
#                      phycocyanin       light  waterTemp  turbidity      chlorA
# timeString
# 2021-01-27 11:00:00    24.430000  483.200012       11.5  23.959999  228.550003
# 2021-01-27 12:00:00    22.549999  603.599976       12.0  22.770000  213.500000
# 2021-01-27 13:00:00    25.370001  455.600006       12.7  23.070000  245.889999
# 2021-01-27 14:00:00    26.309999  407.399994       12.6  22.620001  251.360001
# 2021-01-27 15:00:00    31.010000  308.299988       13.0  21.740000  331.660004
# ...                          ...         ...        ...        ...         ...
# 2024-02-23 05:30:00     8.510000    0.000000       15.0   2.210000   96.839996
# 2024-02-23 06:00:00     8.510000    0.000000       14.9   2.400000   93.339996
# 2024-02-23 06:30:00     9.720000    5.200000       14.8   2.210000   94.510002
# 2024-02-23 07:00:00     9.720000  172.600006       14.8   2.210000   93.339996
# 2024-02-23 07:30:00     9.720000  204.000000       14.9   2.600000   93.339996
#
# [49823 rows x 5 columns]

# %% [markdown]
# ### Missing data

# %%
# Explored data.

index_dtype = df.index.dtype
print("Index Data Type:", index_dtype)
print()
df.info()
# Out:
# Index Data Type: datetime64[ns]
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49823 entries, 2021-01-27 11:00:00 to 2024-02-23 07:30:00
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   phycocyanin  49823 non-null  float64
#  1   light        49823 non-null  float64
#  2   waterTemp    49823 non-null  float64
#  3   turbidity    49823 non-null  float64
#  4   chlorA       49823 non-null  float64
# dtypes: float64(5)
# memory usage: 3.3 MB

# %% [markdown]
# No missing data and all data is in the correct dtype. Although, this does not identify rows that are missing entirely.

# %%
# Checked for missing rows.

# Calulated difference in time between rows
time_diff = df.index.to_series().diff()

# Converted nanoseconds to half hours
time_diff_hours = time_diff / (1.8 * 10**12)

# Printed all the unique values of the calculated time difference
time_diff_hours = time_diff_hours[1:] # Exclude the first row becasue a difference cannot be calculates.
print("Data gaps with number of missing rows:")
print(time_diff_hours.unique())
# Out:
# Data gaps with number of missing rows:
# [  2 148  34   4   1   3  18   9 296   5   6  11  17  57]

# %% [markdown]
# The data has gaps in which the unit must not have been on. The largest gap is 6.25 days which is not too large to impute.

# %%
# Inserted rows where they shoud be in the dataframe.

# Found location of missing rows
expected_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='30T')
missing_index = expected_index.difference(df.index)

# Inserted missing rows with NaN values
for missing_date in missing_index:
    df.loc[missing_date] = pd.Series(dtype=float)

# Sorted the dataframe by index
df = df.sort_index()

# %%
# Confirmed addition of rows.

df
# Out:
#                      phycocyanin       light  waterTemp  turbidity      chlorA
# timeString
# 2021-01-27 11:00:00    24.430000  483.200012       11.5  23.959999  228.550003
# 2021-01-27 11:30:00          NaN         NaN        NaN        NaN         NaN
# 2021-01-27 12:00:00    22.549999  603.599976       12.0  22.770000  213.500000
# 2021-01-27 12:30:00          NaN         NaN        NaN        NaN         NaN
# 2021-01-27 13:00:00    25.370001  455.600006       12.7  23.070000  245.889999
# ...                          ...         ...        ...        ...         ...
# 2024-02-23 05:30:00     8.510000    0.000000       15.0   2.210000   96.839996
# 2024-02-23 06:00:00     8.510000    0.000000       14.9   2.400000   93.339996
# 2024-02-23 06:30:00     9.720000    5.200000       14.8   2.210000   94.510002
# 2024-02-23 07:00:00     9.720000  172.600006       14.8   2.210000   93.339996
# 2024-02-23 07:30:00     9.720000  204.000000       14.9   2.600000   93.339996
#
# [53850 rows x 5 columns]

# %% [markdown]
# I will fill these NaNs later.

# %%
# Rechecked for missing rows.

# Calulated difference in time between rows
time_diff = df.index.to_series().diff()

# Convert nanoseconds to half hours
time_diff_hours = time_diff / (1.8 * 10**12)

# Exclude the first row because a difference cannot be calculated.
time_diff_hours = time_diff_hours[1:]

# Count occurrences of each unique value
unique_counts = time_diff_hours.value_counts()

# Print unique values and their counts
print("Number of missing rows in data gaps and count:")
for value, count in unique_counts.items():
    print(f"{value}: {count}")
# Out:
# Number of missing rows in data gaps and count:
# 0 days 00:00:00.000000001: 53849

# %% [markdown]
# No missing rows.

# %% [markdown]
# ### Values

# %%
# Printed summary statistics.

df.describe()
# Out:
#         phycocyanin         light     waterTemp     turbidity        chlorA
# count  49823.000000  49823.000000  49823.000000  49823.000000  49823.000000
# mean     116.725729    165.370635     18.731209     62.485628    635.287967
# std      172.555341    247.221653      6.328209    100.671570    703.107594
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        9.860000      0.000000     13.700000      4.870000     98.010002
# 50%       54.700001      0.300000     18.000000     16.530001    307.619995
# 75%      164.979996    292.650009     24.299999     75.019997    921.090027
# max     1654.640015   2442.000000     43.400002    400.000000   3000.000000

# %% [markdown]
# Observations from these descriptions:
# 'phycocyanin' - All values are possible. A max of 1655 is unlikely. I will check this when I plot the data.
# 'light' - All values are possible.
# 'waterTemp' - A min of zero is possible as long as it occurs in winter months. A max of 43 is unlikely. I will check this when I plot the data.
# 'turbidity' - All values are possible. A max of 400 is unlikely. I will check this when I plot the data.
# 'chlorA' - All values are possible. A max of 3000 is unlikely. I will check this when I plot the data.

# %%
# Plotted data.

fig, axes = plt.subplots(nrows=len(df.columns), ncols=1, figsize=(10, 2 * len(df.columns)), sharex=True)
for i, column in enumerate(df.columns):
    if i == 0:  # Checked if it's the first plot ('phycocyanin')
        axes[i].plot(df.index, df[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25, color='green')
    else:
        axes[i].plot(df.index, df[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25)
    axes[i].set_ylabel(column)
    axes[i].xaxis.set_major_locator(MonthLocator())
    axes[i].tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observations from these plots:
# light - Small portion of data is too low. The sensor may have been covered with debris.
# All metrics - Maximum values likely caused by debris. Gap in all metrics at end of 8/21. Client has informed me that the unit was flipped upside down in 12/21 and the recorded values are incorrect. I will have to zoom in to get exact dates.

# %%
# Zoomed in on flipped unit time.

# Filtered the DataFrame for the specified time range
flipped_all = df['2021-11-20':'2021-12-10']

# Plotted the metrics
fig, axes = plt.subplots(nrows=len(df.columns), ncols=1, figsize=(10, 2 * len(df.columns)), sharex=True)
for i, column in enumerate(df.columns):
    if i == 0:  # Checked if it's the first plot ('phycocyanin')
        axes[i].plot(flipped_all.index, flipped_all[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25, color='green')
    else:
        axes[i].plot(flipped_all.index, flipped_all[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25)
    axes[i].set_ylabel(column)
    axes[i].xaxis.set_major_locator(DayLocator())
    axes[i].xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))  # Adjust date format as needed
    axes[i].tick_params(axis='x', rotation=90)
    axes[i].set_xlim(pd.to_datetime('2021-11-20'), pd.to_datetime('2021-12-10'))  # Convert string dates to datetime objects
plt.tight_layout()
plt.show()

# %% [raw]
# Looks like the sensor was down from 11/25/21 to 12/06/21.

# %%
# Removed data from all metrics when the unit was flipped over.

# Defined date range
flipped_all = [('2021-11-25', '2021-12-06')]

# Converted to datetime objects
flipped_all = [(pd.to_datetime(start), pd.to_datetime(end)) for start, end in flipped_all]

# Replaced values with NaN for the specified date ranges in all columns
for column in df.columns:
    for start, end in flipped_all:
        df.loc[start:end, column] = float('nan')

# %% [markdown]
# #### Phycocyanin Metric

# %%
# Replaced 1500 and above with NaN in the 'phycocyanin' column.

df.loc[df['phycocyanin'] >= 1500, 'phycocyanin'] = np.nan

# %% [markdown]
# #### Light Metric

# %%
# Zoomed in on low values.

# Filter the DataFrame for the desired date range
filtered_df = df.loc['2021-01-01':'2021-03-01', ['light']]

# Plotted
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 3), sharex=True)
axes.plot(filtered_df.index, filtered_df['light'], marker='o', markersize=1, linestyle='-', linewidth=0.25)
axes.set_ylabel('Light')
axes.xaxis.set_major_locator(DayLocator())
axes.tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks like the sensor was down from 1/28/21 to 1/31/21.

# %%
# Zoomed in on low values.

# Filter the DataFrame for the desired date range
filtered_df = df.loc['2021-03-06':'2021-06-14', ['light']]

# Plotted
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 3), sharex=True)
axes.plot(filtered_df.index, filtered_df['light'], marker='o', markersize=1, linestyle='-', linewidth=0.25)
axes.set_ylabel('Light')
axes.xaxis.set_major_locator(DayLocator())
axes.tick_params(axis='x', rotation=90, labelsize=6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks like the sensor was recording unrealistically low values from 3/10/21 to 6/10/21.

# %%
# Zoomed in on low values.

# Filter the DataFrame for the desired date range
filtered_df = df.loc['2021-08-20':'2021-09-01', ['light']]

# Plotted
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 3), sharex=True)
axes.plot(filtered_df.index, filtered_df['light'], marker='o', markersize=1, linestyle='-', linewidth=0.25)
axes.set_ylabel('Light')
axes.xaxis.set_major_locator(DayLocator())
axes.tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# And down from 8/23/21 to 8/29/21.

# %% [markdown]
# I will replace these NaNs and low values with the mean values of the corresponding dates in 2022 and 2023. Linear interpolation would not be appropriate for these big gaps because light is at zero every night and a straight line would not capture this day/night complexity. However, interpolation is fine for small gaps because there is less complexity.

# %%
# Replaced missing and unrealistic low 'light' values with the mean of corresponding days from 2022 and 2023.

# Created a mask for the specified time ranges
mask = (
    (df.index >= '2021-01-28 00:00:00') & (df.index <= '2021-01-31 23:30:00') |
    (df.index >= '2021-03-10 00:00:00') & (df.index <= '2021-06-10 23:30:00') |
    (df.index >= '2021-08-23 00:00:00') & (df.index <= '2021-08-29 23:30:00') |
    (df.index >= '2021-11-25 00:00:00') & (df.index <= '2021-12-06 23:30:00')
)

# Iterate over each datetime in the specified time ranges
for index, row in df[mask].iterrows():
    # Extract the day, month, and time
    day = index.day
    month = index.month
    time = index.time()
    
    # Filter the dataframe to get the rows with the same day, month, and time, excluding the rows from the mask
    same_day_month_time = df[(df.index.day == day) & (df.index.month == month) & (df.index.time == time) & (~mask)]
    
    # Calculate the average of light values for the same day, month, and time
    avg_light = same_day_month_time['light'].mean()
    
    # Replace the value in the specified time range with the average
    df.loc[index, 'light'] = avg_light

# %% [markdown]
# #### Water Temp Metric

# %%
# Zoomed in on low values.

# Filtered the DataFrame for the desired date range
filtered_df = df.loc['2023-03-20':'2023-04-20', ['waterTemp']]

# Plotted
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 3), sharex=True)
axes.plot(filtered_df.index, filtered_df['waterTemp'], marker='o', markersize=1, linestyle='-', linewidth=0.25)
axes.set_ylabel('waterTemp')
axes.xaxis.set_major_locator(DayLocator())
axes.tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Unrealistically low from 03/30/23 to 04/13/23.

# %%
# Removed unrealistically low 'waterTemp' data.

# Defined date ranges with inaccurate readings
faulty_periods = [('2023-03-30', '2023-04-13')]

# Converted to datetime objects
faulty_periods = [(pd.to_datetime(start), pd.to_datetime(end)) for start, end in faulty_periods]

# Replaced values with NaN for the specified date ranges
for start, end in faulty_periods:
    df.loc[start:end, 'waterTemp'] = float('nan')

# %% [markdown]
# #### Turbidity Metric

# %%
# Replaced 400 and above with NaN in the 'turbidity' column.

df.loc[df['turbidity'] >= 400, 'turbidity'] = np.nan

# %% [markdown]
# #### Chlorophyll-a Metric

# %%
# Replaced 3000 and above with NaN in the 'chlorA' column.

df.loc[df['chlorA'] >= 3000, 'chlorA'] = np.nan

# %%
# Explored data to confirm all NaNs were filled.

index_dtype = df.index.dtype
print("Index Data Type:", index_dtype)
print()
df.info()
# Out:
# Index Data Type: datetime64[ns]
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53850 entries, 2021-01-27 11:00:00 to 2024-02-23 07:30:00
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   phycocyanin  49317 non-null  float64
#  1   light        52557 non-null  float64
#  2   waterTemp    48646 non-null  float64
#  3   turbidity    47191 non-null  float64
#  4   chlorA       49297 non-null  float64
# dtypes: float64(5)
# memory usage: 4.5 MB

# %% [markdown]
# ## Interpolation

# %% [markdown]
# All remaining NaNs values will be interpolated using spline linear interpolation. This interpolation tries to ensure smoothness and continuity in the interpolated curve. I will define the function now but perform for each metric individually.

# %%
# Replaced NaN values using linear spline interpolation.

for col in df.columns:
    nan_indices = df[col].index[df[col].isna()]
    non_nan_indices = df[col].index[~df[col].isna()]

    # Create interpolation function
    interpolation_func = interp1d(non_nan_indices, df[col].dropna(), kind='slinear', fill_value='extrapolate')

    # Interpolate NaN values
    df[col][nan_indices] = interpolation_func(nan_indices)

# %%
# Plotted data.

fig, axes = plt.subplots(nrows=len(df.columns), ncols=1, figsize=(10, 2 * len(df.columns)), sharex=True)
for i, column in enumerate(df.columns):
    if i == 0:  # Checked if it's the first plot ('phycocyanin')
        axes[i].plot(df.index, df[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25, color='green')
    else:
        axes[i].plot(df.index, df[column], marker='o', markersize=0.01, linestyle='-', linewidth=0.25)
    axes[i].set_ylabel(column)
    axes[i].xaxis.set_major_locator(MonthLocator())
    axes[i].tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show()

# %%
# Confirmed all NaNs were filled.

index_dtype = df.index.dtype
print("Index Data Type:", index_dtype)
print()
df.info()
# Out:
# Index Data Type: datetime64[ns]
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53850 entries, 2021-01-27 11:00:00 to 2024-02-23 07:30:00
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   phycocyanin  53850 non-null  float64
#  1   light        53850 non-null  float64
#  2   waterTemp    53850 non-null  float64
#  3   turbidity    53850 non-null  float64
#  4   chlorA       53850 non-null  float64
# dtypes: float64(5)
# memory usage: 4.5 MB

# %% [markdown]
# # Data Save

# %%
# Saved dataframe.

df.to_excel('Lake_Fictitious_AquaRealTime_Data_Cleaned.xlsx', index=True)
